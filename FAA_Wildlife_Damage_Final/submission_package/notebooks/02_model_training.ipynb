# %% [markdown]
# # Model Training
# Logistic Regression, Decision Tree, RandomForest 모델 학습 결과를 확인합니다.

# %%
import pandas as pd
pd.read_csv('../outputs/metrics/metrics_table.csv')
